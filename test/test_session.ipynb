# %%
import sys
sys.path.insert(1,'../../ipage/scripts/')
import ipage

# %%
de_genes, de_profile = ipage.read_expression_file('bladder.exp', sep='\t')

# %%
annotation_name = 'msig_db'
de_gene_format = 'refseq'
annotation_gene_format = 'gs'
output_name = 'stdout'
annotation_dir = '../annotation_dir'
ipage_hits = ipage.ipage(de_genes, de_profile, annotation_name, output_name=output_name, de_ft=de_gene_format, ann_ft=annotation_gene_format, annotation_dir=annotation_dir)

# %%
ipage_hits.head()
# Out:
#                                           Group       CMI    Z-score  \
# 0                              GO_VACUOLAR_PART  0.004257  15.457331
# 1  GO_NUCLEAR_TRANSCRIPTIONAL_REPRESSOR_COMPLEX  0.003778   7.165859
# 2                  GO_CLATHRIN_SCULPTED_VESICLE  0.003533   7.168418
# 3            GO_FICOLIN_1_RICH_GRANULE_MEMBRANE  0.003209   5.684368
# 4           REACTOME_CTLA4_INHIBITORY_SIGNALING  0.003207   6.962466
#
#   Regulation
# 0         UP
# 1         UP
# 2         UP
# 3         UP
# 4         UP
